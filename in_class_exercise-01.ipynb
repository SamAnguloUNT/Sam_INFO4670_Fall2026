# %% [markdown]
# <a href="https://colab.research.google.com/github/SamAnguloUNT/Sam_INFO4670_Fall2026/blob/main/in_class_exercise-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("My first python code")
# Out:
# My first python code

# %% [markdown]
# This is just some code to add to my github repo.
